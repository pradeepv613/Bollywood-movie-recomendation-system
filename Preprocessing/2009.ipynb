# %%
import pandas as pd
import numpy as np
import requests
import bs4 as bs
import urllib.request

link = "https://en.wikipedia.org/wiki/List_of_Bollywood_films_of_2009"
source = urllib.request.urlopen(link).read()

soup = bs.BeautifulSoup(source,'lxml')



tables = soup.find_all('table',class_='wikitable')

len(tables)
# Out:
# 5

# %%
df1 = pd.read_html(str(tables[4]))[0]
df2 = pd.read_html(str(tables[1]))[0]
df3 = pd.read_html(str(tables[2]))[0]
df4 = pd.read_html(str(tables[3]).replace("'1\"\'",'"1"'))[0] # avoided "ValueError: invalid literal for int() with base 10: '1"'

# %%
df1
# Out:
#    Opening  Opening.1                               Title  \
# 0      OCT        2.0                     Do Knot Disturb
# 1      OCT        2.0                         Wake Up Sid
# 2      OCT        9.0                        Acid Factory
# 3      OCT       16.0            All the Best: Fun Begins
# 4      OCT       16.0                                Blue
# 5      OCT       16.0                Main Aurr Mrs Khanna
# 6      OCT       23.0                        Bal Ganesh 2
# 7      OCT       23.0                       Fruit and Nut
# 8      OCT       23.0                       Love Ka Tadka
# 9      OCT       30.0                       London Dreams
# 10     OCT       30.0                              Aladin
# 11     NOV        6.0          Ajab Prem Ki Ghazab Kahani
# 12     NOV        6.0                                Jail
# 13     NOV       13.0                            Tum Mile
# 14     NOV       13.0                     Aao Wish Karein
# ...

# %%
df = df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)

# %%
#df3 = pd.read_html(str(tables[1]))[0]
 # avoided "ValueError: invalid literal for int() with base 10: '1"'
print(df3)
# Out:
#    Opening  Opening.1                         Title             Director  \
# 0      APR          3                8 x 10 Tasveer      Nagesh Kukunoor
# 1      APR         10                 Ek Se Bure Do              Tarique
# 2      APR         10          Pal Pal Dil Ke Saath      V Krishna Kumar
# 3      APR         10                  Coffee House        Gurbir Grewal
# 4      APR         10                   School Days           Dilip Sood
# 5      APR         10                   Royal Utsav        Ravi K. Patwa
# 6      APR         17  Chowrasta Crossroads of Love           Anjan Dutt
# 7      APR         17                  Meri Padosan        Prakash Saini
# 8      APR         22                      Sikandar           Piyush Jha
# 9      MAY         15                            99         Raj and D.K.
# 10     MAY         15    Suno Na, Ek Nanhi Awaaz[2]        Amy Thanawala
# 11     MAY         22               Detective Naani    Romilla Mukherjee
# ...

# %%
#df.to_csv('film_2009.csv', header=False, index=False)

# %%
df.isnull().sum()
# Out:
# Opening      0
# Opening.1    4
# Title        4
# Director     4
# Cast         5
# Genre        6
# dtype: int64

# %%
df.dropna()
# Out:
#     Opening  Opening.1                     Title            Director  \
# 0       OCT        2.0           Do Knot Disturb        David Dhawan
# 1       OCT        2.0               Wake Up Sid        Ayan Mukerji
# 2       OCT        9.0              Acid Factory        Suparn Verma
# 3       OCT       16.0  All the Best: Fun Begins        Rohit Shetty
# 4       OCT       16.0                      Blue     Anthony D'souza
# ..      ...        ...                       ...                 ...
# 101     SEP       11.0                Vaada Raha        Samir Karnik
# 102     SEP       18.0         Dil Bole Hadippa!        Anurag Singh
# 103     SEP       18.0                    Wanted         Prabhu Deva
# 104     SEP       18.0              Blue Oranges      Rajesh Ganguly
# 105     SEP       25.0      What's Your Raashee?  Ashutosh Gowarikar
#
#                                                   Cast  \
# 0    Govinda, Riteish Deshmukh, Lara Dutta, Sushmit...
# ...

# %%
cd /Users/pradeepvaddigadda/desktop
# Out:
# /Users/pradeepvaddigadda/Desktop

# %%
df.to_csv('cleanedfilm_2009.csv', header=True, index=True)
