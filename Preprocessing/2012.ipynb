# %%
import pandas as pd
import numpy as np
import requests
import bs4 as bs
import urllib.request

link = "https://en.wikipedia.org/wiki/List_of_Bollywood_films_of_2012"
source = urllib.request.urlopen(link).read()

soup = bs.BeautifulSoup(source,'lxml')



tables = soup.find_all('table',class_='wikitable')

len(tables)
# Out:
# 5

# %%
df1 = pd.read_html(str(tables[4]))[0]
df2 = pd.read_html(str(tables[1]))[0]
df3 = pd.read_html(str(tables[2]))[0]
df4 = pd.read_html(str(tables[3]).replace("'1\"\'",'"1"'))[0] # avoided "ValueError: invalid literal for int() with base 10: '1"'

# %%
df1
# Out:
#    Opening  Opening.1                            Title  \
# 0      OCT          5                 English Vinglish
# 1      OCT          5          Kismet Love Paisa Dilli
# 2      OCT         12                           Aiyyaa
# 3      OCT         12                            Login
# 4      OCT         12                       Chittagong
# 5      OCT         12                     Delhi Safari
# 6      OCT         12                    Bhoot Returns
# 7      OCT         19              Student of the Year
# 8      OCT         24                       Chakravyuh
# 9      OCT         26                 Ajab Gazabb Love
# 10     OCT         26                             Rush
# 11     NOV          2     Luv Shuv Tey Chicken Khurana
# 12     NOV          2           1920: The Evil Returns
# 13     NOV          2                 Ata Pata Laapata
# 14     NOV          2                      Sons of Ram
# 15     NOV          2          Future To Bright Hai Ji
# ...

# %%
df = df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)

# %%
#df3 = pd.read_html(str(tables[1]))[0]
 # avoided "ValueError: invalid literal for int() with base 10: '1"'
print(df3)
# Out:
#    Opening  Opening.1                                  Title  \
# 0      APR          5                            Housefull 2
# 1      APR         13                            Bittoo Boss
# 2      APR         13                            Vicky Donor
# 3      APR         13               Ab Hoga Dharna Unlimited
# 4      APR         20                             Hate Story
# 5      APR         20                  Chhodo Kal Ki Baatein
# 6      APR         27                                   Tezz
# 7      APR         27                   Life Ki Toh Lag Gayi
# 8      MAY          4                               Jannat 2
# 9      MAY          4                                 Fatso!
# 10     MAY          4                             The Forest
# 11     MAY          4                     Love, Lies & Seeta
# 12     MAY         11                         Dangerous Ishq
# 13     MAY         11  Chhota Bheem And The Curse Of Damyaan
# ...

# %%
#df.to_csv('film_2012.csv', header=False, index=False)

# %%
df
# Out:
#     Opening  Opening.1                    Title           Genre  \
# 0       OCT          5         English Vinglish           Drama
# 1       OCT          5  Kismet Love Paisa Dilli          Comedy
# 2       OCT         12                   Aiyyaa         Rom-Com
# 3       OCT         12                    Login  Drama/Thriller
# 4       OCT         12               Chittagong           Drama
# ..      ...        ...                      ...             ...
# 99      SEP         14                   Barfi!  Romance/Comedy
# 100     SEP         14  Jeena Hai Toh Thok Daal           Drama
# 101     SEP         21                  Heroine     Adult/Drama
# 102     SEP         28  Kamaal Dhamaal Malamaal          Comedy
# 103     SEP         28         OMG – Oh My God!  Comedy/Fantasy
#
#               Director                                               Cast
# 0         Gauri Shinde  Sridevi, Priya Anand, Mehdi Nebbou, Amitabh Ba...
# ...

# %%
df.isnull().sum()
# Out:
# Opening      0
# Opening.1    0
# Title        0
# Genre        0
# Director     0
# Cast         0
# dtype: int64

# %%
cd /Users/pradeepvaddigadda/desktop
# Out:
# /Users/pradeepvaddigadda/Desktop

# %%
df.to_csv('cleanedfilm_2012.csv', header=True, index=True)
