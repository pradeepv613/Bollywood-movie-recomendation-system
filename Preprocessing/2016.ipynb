# %%
import pandas as pd
import numpy as np
import requests
import bs4 as bs
import urllib.request

link = "https://en.wikipedia.org/wiki/List_of_Bollywood_films_of_2016"
source = urllib.request.urlopen(link).read()

soup = bs.BeautifulSoup(source,'lxml')



tables = soup.find_all('table',class_='wikitable')

len(tables)
# Out:
# 5

# %%
df1 = pd.read_html(str(tables[4]))[0]
df2 = pd.read_html(str(tables[1]))[0]
df3 = pd.read_html(str(tables[2]))[0]
df4 = pd.read_html(str(tables[3]).replace("'1\"\'",'"1"'))[0] # avoided "ValueError: invalid literal for int() with base 10: '1"'

# %%
df2
# Out:
#    Opening  Opening.1                          Title                    Genre  \
# 0      JAN          8                          Wazir                 Thriller
# 1      JAN         15                 Chalk n Duster                    Drama
# 2      JAN         15              Rebellious Flower                   Biopic
# 3      JAN         22                        Airlift             War/Thriller
# 4      JAN         22                          Jugni            Musical drama
# 5      JAN         22           Kyaa Kool Hain Hum 3             Adult comedy
# 6      JAN         29                  Saala Khadoos                   Sports
# 7      JAN         29                     Mastizaade             Adult comedy
# 8      FEB          5               Sanam Teri Kasam                  Romance
# 9      FEB          5             Ghayal: Once Again             Action/drama
# 10     FEB         12                         Fitoor            Romance/drama
# ...

# %%
df = df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)

# %%
#df3 = pd.read_html(str(tables[1]))[0]
 # avoided "ValueError: invalid literal for int() with base 10: '1"'
print(df3)
# Out:
#    Opening  Opening.1                     Title                  Director  \
# 0      APR          1                   Ki & Ka                  R. Balki
# 1      APR          8                Love Games              Vikram Bhatt
# 2      APR          8        The Blueberry Hunt               Anup Kurien
# 3      APR         10        Kaafiron Ki Namaaz         Ram Ramesh Sharma
# 4      APR         15                       Fan            Maneesh Sharma
# 5      APR         22        Nil Battey Sannata       Ashwini Iyer Tiwari
# 6      APR         22                 Laal Rang          Syed Ahmad Afzal
# 7      APR         22       Santa Banta Pvt Ltd           Akashdeep Sabir
# 8      APR         29                    Baaghi               Sabbir Khan
# 9      APR         29           Shortcut Safari            Amitabha Singh
# 10     MAY          6           One Night Stand     Jasmine Moses D'Souza
# 11     MAY          6                   Traffic             Rajesh Pillai
# ...

# %%
#df.to_csv('film_2016.csv', header=False, index=False)

# %%
df
# Out:
#     Opening  Opening.1                         Title  \
# 0       OCT          7                        Mirzya
# 1       OCT          7   MSG: The Warrior Lion Heart
# 2       OCT          7            Tutak Tutak Tutiya
# 3       OCT         14                          Anna
# 4       OCT         14     Motu Patlu: King of Kings
# ..      ...        ...                           ...
# 115     SEP         23                       Parched
# 116     SEP         23                         Banjo
# 117     SEP         23                Days of Tafree
# 118     SEP         23                       Wah Taj
# 119     SEP         30  M.S. Dhoni: The Untold Story
#
#                                       Director  \
# 0                      Rakeysh Omprakash Mehra
# 1    Gurmeet Ram Rahim Singh, Honeypreet Insan
# 2                                  A. L. Vijay
# 3                           Shashank Udapurkar
# 4                            Suhas D. Kadavand
# ...

# %%
df.isnull().sum()
# Out:
# Opening        0
# Opening.1      0
# Title          0
# Director       1
# Cast           1
# Genre          0
# Studio       119
# Ref.          13
# dtype: int64

# %%
df["Studio"].fillna("unknown", inplace = True)

# %%
df.isnull().sum()
# Out:
# Opening       0
# Opening.1     0
# Title         0
# Director      1
# Cast          1
# Genre         0
# Studio        0
# Ref.         13
# dtype: int64

# %%
df = df.drop('Ref.', 1)

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#     Opening  Opening.1                         Title  \
# 0       OCT          7                        Mirzya
# 1       OCT          7   MSG: The Warrior Lion Heart
# 2       OCT          7            Tutak Tutak Tutiya
# 3       OCT         14                          Anna
# 4       OCT         14     Motu Patlu: King of Kings
# ..      ...        ...                           ...
# 115     SEP         23                       Parched
# 116     SEP         23                         Banjo
# 117     SEP         23                Days of Tafree
# 118     SEP         23                       Wah Taj
# 119     SEP         30  M.S. Dhoni: The Untold Story
#
#                                       Director  \
# 0                      Rakeysh Omprakash Mehra
# 1    Gurmeet Ram Rahim Singh, Honeypreet Insan
# 2                                  A. L. Vijay
# 3                           Shashank Udapurkar
# 4                            Suhas D. Kadavand
# ...

# %%
cd /Users/pradeepvaddigadda/desktop
# Out:
# /Users/pradeepvaddigadda/Desktop

# %%
df.to_csv('cleanedfilm_2016.csv', header=True, index=True)
