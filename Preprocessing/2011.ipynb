# %%
import pandas as pd
import numpy as np
import requests
import bs4 as bs
import urllib.request

link = "https://en.wikipedia.org/wiki/List_of_Bollywood_films_of_2011"
source = urllib.request.urlopen(link).read()

soup = bs.BeautifulSoup(source,'lxml')



tables = soup.find_all('table',class_='wikitable')

len(tables)
# Out:
# 5

# %%
df1 = pd.read_html(str(tables[4]))[0]
df2 = pd.read_html(str(tables[1]))[0]
df3 = pd.read_html(str(tables[2]))[0]
df4 = pd.read_html(str(tables[3]).replace("'1\"\'",'"1"'))[0] # avoided "ValueError: invalid literal for int() with base 10: '1"'

# %%
df1
# Out:
#    Opening  Opening.1                      Title                 Genre  \
# 0      OCT          6                    Rascals         Comedy/Action
# 1      OCT          7      Love Breakups Zindagi              Romantic
# 2      OCT         14            My Friend Pinto  Romance Comedy Crime
# 3      OCT         14  Mujhse Fraaandship Karoge        Comedy/Romance
# 4      OCT         14                        Mod         Romance/Drama
# 5      OCT         14                     Aazaan       Action/Thriller
# 6      OCT         26                     Ra.One         Action/Sci-Fi
# 7      OCT         27           Tell Me O Kkhuda                 Drama
# 8      OCT         27                  Damadamm!                Comedy
# 9      NOV          4                       Loot                Comedy
# 10     NOV          4        Miley Naa Miley Hum         Romance/Drama
# 11     NOV         11                   Rockstar         Romance/Drama
# ...

# %%
df = df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)

# %%
#df3 = pd.read_html(str(tables[1]))[0]
 # avoided "ValueError: invalid literal for int() with base 10: '1"'
print(df3)
# Out:
#    Opening  Opening.1                   Title                    Genre  \
# 0      APR          1                    Game           Mystery/Action
# 1      APR          1               F.A.L.T.U  Satire/Comedy/Teen film
# 2      APR          1       Memories in March                    Drama
# 3      APR          8               Thank You                   Comedy
# 4      APR         15          Teen Thay Bhai                    Drama
# 5      APR         22           Dum Maaro Dum                 Thriller
# 6      APR         22                Zokkomon       Superhero/Children
# 7      APR         28        Shor in the City               Drama/Cult
# 8      APR         29             Chalo Dilli        Comedy Road movie
# 9      APR         29                    I Am             Social/Drama
# 10     APR         29            Naughty @ 40                   Comedy
# 11     MAY          6          Luv Ka The End              Teen/Comedy
# ...

# %%
#df.to_csv('film_2011.csv', header=False, index=False)

# %%
df
# Out:
#     Opening  Opening.1                      Title                 Genre  \
# 0       OCT        6.0                    Rascals         Comedy/Action
# 1       OCT        7.0      Love Breakups Zindagi              Romantic
# 2       OCT       14.0            My Friend Pinto  Romance Comedy Crime
# 3       OCT       14.0  Mujhse Fraaandship Karoge        Comedy/Romance
# 4       OCT       14.0                        Mod         Romance/Drama
# ..      ...        ...                        ...                   ...
# 103     SEP       30.0            Tere Mere Phere       Romantic/Comedy
# 104     SEP       30.0                Chargesheet        Drama/Thriller
# 105     SEP       30.0      Na Jaane Kabse hum hi               Romance
# 106     SEP        NaN                        NaN                   NaN
# 107     SEP        NaN                        NaN                   NaN
#
#             Director                                               Cast   Ref
# ...

# %%
df.isnull().sum()
# Out:
# Opening       0
# Opening.1     2
# Title         3
# Genre         3
# Director      3
# Cast          4
# Ref          25
# dtype: int64

# %%
df.drop(['Ref'],1)
# Out:
#     Opening  Opening.1                      Title                 Genre  \
# 0       OCT        6.0                    Rascals         Comedy/Action
# 1       OCT        7.0      Love Breakups Zindagi              Romantic
# 2       OCT       14.0            My Friend Pinto  Romance Comedy Crime
# 3       OCT       14.0  Mujhse Fraaandship Karoge        Comedy/Romance
# 4       OCT       14.0                        Mod         Romance/Drama
# ..      ...        ...                        ...                   ...
# 103     SEP       30.0            Tere Mere Phere       Romantic/Comedy
# 104     SEP       30.0                Chargesheet        Drama/Thriller
# 105     SEP       30.0      Na Jaane Kabse hum hi               Romance
# 106     SEP        NaN                        NaN                   NaN
# 107     SEP        NaN                        NaN                   NaN
#
#             Director                                               Cast
# ...

# %%
df.dropna()
# Out:
#     Opening  Opening.1                      Title                 Genre  \
# 0       OCT        6.0                    Rascals         Comedy/Action
# 1       OCT        7.0      Love Breakups Zindagi              Romantic
# 2       OCT       14.0            My Friend Pinto  Romance Comedy Crime
# 3       OCT       14.0  Mujhse Fraaandship Karoge        Comedy/Romance
# 5       OCT       14.0                     Aazaan       Action/Thriller
# ..      ...        ...                        ...                   ...
# 101     SEP       30.0            Hum Tum Shabana        Romance/Comedy
# 102     SEP       30.0   Saheb, Biwi Aur Gangster       Action/Thriller
# 103     SEP       30.0            Tere Mere Phere       Romantic/Comedy
# 104     SEP       30.0                Chargesheet        Drama/Thriller
# 105     SEP       30.0      Na Jaane Kabse hum hi               Romance
#
#              Director                                               Cast   Ref
# ...

# %%
cd /Users/pradeepvaddigadda/desktop
# Out:
# /Users/pradeepvaddigadda/Desktop

# %%
df.to_csv('cleanedfilm_2011.csv', header=True, index=True)
