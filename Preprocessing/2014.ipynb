# %%
import pandas as pd
import numpy as np
import requests
import bs4 as bs
import urllib.request

link = "https://en.wikipedia.org/wiki/List_of_Bollywood_films_of_2014"
source = urllib.request.urlopen(link).read()

soup = bs.BeautifulSoup(source,'lxml')



tables = soup.find_all('table',class_='wikitable')

len(tables)
# Out:
# 5

# %%
df1 = pd.read_html(str(tables[4]))[0]
df2 = pd.read_html(str(tables[1]))[0]
df3 = pd.read_html(str(tables[2]))[0]
df4 = pd.read_html(str(tables[3]).replace("'1\"\'",'"1"'))[0] # avoided "ValueError: invalid literal for int() with base 10: '1"'

# %%
df1
# Out:
#    Opening  Opening.1                           Title                   Genre  \
# 0      OCT          2                      Bang Bang!          Action/Romance
# 1      OCT          2                          Haider                   Drama
# 2      OCT          2                           Spark                   Drama
# 3      OCT         10                       Jigariyaa                 Romance
# 4      OCT         10        Ekkees Toppon Ki Salaami        Political Satire
# 5      OCT         10                       Tamanchey           Crime/Romance
# 6      OCT         17                   Mumbai 125 KM                  Horror
# 7      OCT         17                    Sonali Cable            Comedy/Drama
# 8      OCT         24                  Happy New Year           Action/Comedy
# 9      OCT         31                       Fireflies                   Drama
# 10     OCT         31  Roar: Tigers of the Sunderbans            Drama/Action
# ...

# %%
df = df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)

# %%
#df3 = pd.read_html(str(tables[1]))[0]
 # avoided "ValueError: invalid literal for int() with base 10: '1"'
print(df3)
# Out:
#    Opening  Opening.1                                 Title  \
# 0      APR        4.0                          Ebn-E-Batuta
# 1      APR        4.0                        Honour Killing
# 2      APR        4.0                                   Jal
# 3      APR        4.0                        Main Tera Hero
# 4      APR       11.0                    Bhoothnath Returns
# 5      APR       18.0                              2 States
# 6      APR       18.0                     Dekh Tamasha Dekh
# 7      APR       18.0                        Lucky Kabootar
# 8      APR       25.0              Kaanchi: The Unbreakable
# 9      APR       25.0                         Revolver Rani
# 10     APR       25.0                          Samrat & Co.
# 11     MAY        2.0                          Purani Jeans
# 12     MAY        2.0                  Kya Dilli Kya Lahore
# 13     MAY        2.0                       Angry Young Man
# 14     MAY        2.0                   Kahin Hai Mera Pyar
# ...

# %%
#df.to_csv('film_2014.csv', header=False, index=False)

# %%
df
# Out:
#     Opening  Opening.1                           Title             Genre  \
# 0       OCT        2.0                      Bang Bang!    Action/Romance
# 1       OCT        2.0                          Haider             Drama
# 2       OCT        2.0                           Spark             Drama
# 3       OCT       10.0                       Jigariyaa           Romance
# 4       OCT       10.0        Ekkees Toppon Ki Salaami  Political Satire
# ..      ...        ...                             ...               ...
# 141     SEP       26.0                          3 A.M.            Horror
# 142     SEP       26.0            Chaarfutiya Chhokare          Thriller
# 143     SEP       26.0                     Desi Kattey      Drama/Action
# 144     SEP       26.0         Meinu Ek Ladki Chaahiye     Social satire
# 145     SEP       26.0  Balwinder Singh Famous Ho Gaya            Comedy
#
#                Director                                               Cast  \
# ...

# %%
df.isnull().sum()
# Out:
# Opening       0
# Opening.1    10
# Title        10
# Genre        10
# Director     10
# Cast         10
# Source       12
# dtype: int64

# %%
df.dropna()
# Out:
#     Opening  Opening.1                           Title             Genre  \
# 0       OCT        2.0                      Bang Bang!    Action/Romance
# 1       OCT        2.0                          Haider             Drama
# 4       OCT       10.0        Ekkees Toppon Ki Salaami  Political Satire
# 5       OCT       10.0                       Tamanchey     Crime/Romance
# 6       OCT       17.0                   Mumbai 125 KM            Horror
# ..      ...        ...                             ...               ...
# 141     SEP       26.0                          3 A.M.            Horror
# 142     SEP       26.0            Chaarfutiya Chhokare          Thriller
# 143     SEP       26.0                     Desi Kattey      Drama/Action
# 144     SEP       26.0         Meinu Ek Ladki Chaahiye     Social satire
# 145     SEP       26.0  Balwinder Singh Famous Ho Gaya            Comedy
#
#                Director                                               Cast  \
# ...

# %%
cd /Users/pradeepvaddigadda/desktop
# Out:
# /Users/pradeepvaddigadda/Desktop

# %%
df.to_csv('cleanedfilm_2014.csv', header=True, index=True)
