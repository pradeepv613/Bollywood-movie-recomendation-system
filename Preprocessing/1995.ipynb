# %%
import pandas as pd
import numpy as np
import requests
import bs4 as bs
import urllib.request

# %%
#pip install requests[security]

# %%
link = "https://en.wikipedia.org/wiki/List_of_Bollywood_films_of_1995"

# %%
source = urllib.request.urlopen(link).read()
soup = bs.BeautifulSoup(source,'lxml')

# %%
tables = soup.find_all('table',class_='wikitable')

# %%
len(tables)
# Out:
# 7

# %%
df1 = pd.read_html(str(tables[4]))[0]
df2 = pd.read_html(str(tables[1]))[0]
df3 = pd.read_html(str(tables[2]))[0]
df4 = pd.read_html(str(tables[3]).replace("'1\"\'",'"1"'))[0] # avoided "ValueError: invalid literal for int() with base 10: '1"'

# %%
df = df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)

# %%
#df3 = pd.read_html(str(tables[1]))[0]
 # avoided "ValueError: invalid literal for int() with base 10: '1"'

# %%
print(df1)
# Out:
#    Opening  Opening.1                        Title           Director  \
# 0      OCT          6                      Barsaat  Rajkumar Santoshi
# 1      OCT         20  Dilwale Dulhania Le Jayenge      Aditya Chopra
# 2      OCT         20                      Yaraana       David Dhawan
# 3      OCT         27            Hum Sab Chor Hain     Ambrish Sangal
# 4      NOV         10                  Ram Shastra       Sanjay Gupta
# 5      NOV         17                   Angrakshak          Ravi Raja
# 6      NOV         30          Akele Hum Akele Tum       Mansoor Khan
# 7      NOV         30                    Ram Jaane        Rajiv Mehra
# 8      DEC          8                  The Gambler     Dayal Nihalani
# 9      DEC         22                     Trimurti     Mukul S. Anand
# 10     DEC         29                     Haqeeqat         Kuku Kohli
#
#                                                  Cast          Genre
# ...

# %%
#df = df3

# %%
df
# Out:
#    Opening  Opening.1                        Title             Director  \
# 0      OCT        6.0                      Barsaat    Rajkumar Santoshi
# 1      OCT       20.0  Dilwale Dulhania Le Jayenge        Aditya Chopra
# 2      OCT       20.0                      Yaraana         David Dhawan
# 3      OCT       27.0            Hum Sab Chor Hain       Ambrish Sangal
# 4      NOV       10.0                  Ram Shastra         Sanjay Gupta
# 5      NOV       17.0                   Angrakshak            Ravi Raja
# 6      NOV       30.0          Akele Hum Akele Tum         Mansoor Khan
# 7      NOV       30.0                    Ram Jaane          Rajiv Mehra
# 8      DEC        8.0                  The Gambler       Dayal Nihalani
# 9      DEC       22.0                     Trimurti       Mukul S. Anand
# 10     DEC       29.0                     Haqeeqat           Kuku Kohli
# 11     JAN        6.0                     Guneghar         Vikram Bhatt
# ...

# %%
cd Users/pradeepvaddigadda/desktop
# Out:
# [Errno 2] No such file or directory: 'Users/pradeepvaddigadda/desktop'
# /Users/pradeepvaddigadda

# %%
df.to_csv('film_1995.csv', header=False, index=False)

# %%
df.isnull().sum()
# Out:
# Opening       0
# Opening.1     1
# Title         2
# Director      2
# Cast          2
# Genre        14
# dtype: int64

# %%
df=df.dropna()

# %%
cd /Users/pradeepvaddigadda/desktop
# Out:
# /Users/pradeepvaddigadda/Desktop

# %%
df.to_csv('cleanedfilm_1995.csv', header=True, index=True)
