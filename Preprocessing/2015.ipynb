# %%
import pandas as pd
import numpy as np
import requests
import bs4 as bs
import urllib.request

link = "https://en.wikipedia.org/wiki/List_of_Bollywood_films_of_2015"
source = urllib.request.urlopen(link).read()

soup = bs.BeautifulSoup(source,'lxml')



tables = soup.find_all('table',class_='wikitable')

len(tables)
# Out:
# 5

# %%
df1 = pd.read_html(str(tables[4]))[0]
df2 = pd.read_html(str(tables[1]))[0]
df3 = pd.read_html(str(tables[2]))[0]
df4 = pd.read_html(str(tables[3]).replace("'1\"\'",'"1"'))[0] # avoided "ValueError: invalid literal for int() with base 10: '1"'

# %%
df1
# Out:
#    Opening  Opening.1                       Title           Genre  \
# 0      OCT          2             Singh Is Bliing          Comedy
# 1      OCT          2                      Talvar        Thriller
# 2      OCT          9                      Jazbaa    Action/drama
# 3      OCT         16                 Bumper Draw          Comedy
# 4      OCT         16      Chinar Daastaan-E-Ishq  Romantic/drama
# 5      OCT         16        Pyaar Ka Punchnama 2          Comedy
# 6      OCT         16              Wedding Pullav          Comedy
# 7      OCT         22                   Shaandaar  Romance/comedy
# 8      OCT         30                       Titli           Crime
# 9      OCT         30            Main Aur Charles        Thriller
# 10     OCT         30   Once Upon a Time in Bihar       Political
# 11     OCT         30                Guddu Ki Gun          Comedy
# 12     OCT         30               Love Exchange         Romance
# ...

# %%
df = df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)

# %%
#df3 = pd.read_html(str(tables[1]))[0]
 # avoided "ValueError: invalid literal for int() with base 10: '1"'
print(df3)
# Out:
#    Opening  Opening.1                             Title  \
# 0      APR          3        Detective Byomkesh Bakshy!
# 1      APR          3                    Luckhnowi Ishq
# 2      APR         10                Dharam Sankat Mein
# 3      APR         10                   Ek Paheli Leela
# 4      APR         17                             Court
# 5      APR         17            Margarita with a Straw
# 6      APR         17                             Mr. X
# 7      APR         17             NH-8 Road to Nidhivan
# 8      APR         17  Ek Adbhut Dakshina Guru Dakshina
# 9      APR         24                  Ishq Ke Parindey
# 10     APR         24                   Kaagaz Ke Fools
# 11     MAY          1                    Gabbar Is Back
# 12     MAY          1                 Sabki Bajegi Band
# 13     MAY          8               Kuch Kuch Locha Hai
# 14     MAY          8                              Piku
# 15     MAY         15                     Bombay Velvet
# ...

# %%
#df.to_csv('film_2015.csv', header=False, index=False)

# %%
df
# Out:
#     Opening  Opening.1                    Title           Genre  \
# 0       OCT        2.0          Singh Is Bliing          Comedy
# 1       OCT        2.0                   Talvar        Thriller
# 2       OCT        9.0                   Jazbaa    Action/drama
# 3       OCT       16.0              Bumper Draw          Comedy
# 4       OCT       16.0   Chinar Daastaan-E-Ishq  Romantic/drama
# ..      ...        ...                      ...             ...
# 109     SEP       25.0           Calendar Girls           Drama
# 110     SEP       25.0             Bhaag Johnny           Drama
# 111     SEP       25.0                 Time Out           Drama
# 112     SEP       25.0  Mumbhaii - The Gangster     Crime/Drama
# 113     SEP        NaN                      NaN             NaN
#
#               Director                                               Cast  \
# 0          Prabhu Deva                          Akshay Kumar, Amy Jackson
# ...

# %%
df.isnull().sum()
# Out:
# Opening      0
# Opening.1    1
# Title        1
# Genre        1
# Director     1
# Cast         1
# Source       6
# dtype: int64

# %%
df.drop(['Source'],1)
# Out:
#     Opening  Opening.1                    Title           Genre  \
# 0       OCT        2.0          Singh Is Bliing          Comedy
# 1       OCT        2.0                   Talvar        Thriller
# 2       OCT        9.0                   Jazbaa    Action/drama
# 3       OCT       16.0              Bumper Draw          Comedy
# 4       OCT       16.0   Chinar Daastaan-E-Ishq  Romantic/drama
# ..      ...        ...                      ...             ...
# 109     SEP       25.0           Calendar Girls           Drama
# 110     SEP       25.0             Bhaag Johnny           Drama
# 111     SEP       25.0                 Time Out           Drama
# 112     SEP       25.0  Mumbhaii - The Gangster     Crime/Drama
# 113     SEP        NaN                      NaN             NaN
#
#               Director                                               Cast
# 0          Prabhu Deva                          Akshay Kumar, Amy Jackson
# ...

# %%
df.dropna()
# Out:
#     Opening  Opening.1                    Title         Genre  \
# 0       OCT        2.0          Singh Is Bliing        Comedy
# 1       OCT        2.0                   Talvar      Thriller
# 2       OCT        9.0                   Jazbaa  Action/drama
# 3       OCT       16.0              Bumper Draw        Comedy
# 5       OCT       16.0     Pyaar Ka Punchnama 2        Comedy
# ..      ...        ...                      ...           ...
# 108     SEP       25.0   Kis Kisko Pyaar Karoon        Comedy
# 109     SEP       25.0           Calendar Girls         Drama
# 110     SEP       25.0             Bhaag Johnny         Drama
# 111     SEP       25.0                 Time Out         Drama
# 112     SEP       25.0  Mumbhaii - The Gangster   Crime/Drama
#
#               Director                                               Cast  \
# 0          Prabhu Deva                          Akshay Kumar, Amy Jackson
# ...

# %%
cd /Users/pradeepvaddigadda/desktop
# Out:
# /Users/pradeepvaddigadda/Desktop

# %%
df.to_csv('cleanedfilm_2015.csv', header=True, index=True)
