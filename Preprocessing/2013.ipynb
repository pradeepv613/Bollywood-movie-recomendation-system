# %%
import pandas as pd
import numpy as np
import requests
import bs4 as bs
import urllib.request

link = "https://en.wikipedia.org/wiki/List_of_Bollywood_films_of_2013"
source = urllib.request.urlopen(link).read()

soup = bs.BeautifulSoup(source,'lxml')



tables = soup.find_all('table',class_='wikitable')

len(tables)
# Out:
# 5

# %%
df1 = pd.read_html(str(tables[4]))[0]
df2 = pd.read_html(str(tables[1]))[0]
df3 = pd.read_html(str(tables[2]))[0]
df4 = pd.read_html(str(tables[3]).replace("'1\"\'",'"1"'))[0] # avoided "ValueError: invalid literal for int() with base 10: '1"'

# %%
df1
# Out:
#    Opening  Opening.1                           Title                 Genre  \
# 0      OCT        2.0                        Besharam         Comedy/Action
# 1      OCT       11.0               War Chhod Na Yaar            War comedy
# 2      OCT       11.0                  Baat Bann Gayi                Comedy
# 3      OCT       11.0                   Ek Thee Sanam                 Drama
# 4      OCT       11.0          Paapi - Ek Satya Katha                 Crime
# 5      OCT       16.0                            Boss                Masala
# 6      OCT       18.0                          Shahid       Drama/Biography
# 7      OCT       25.0                   Wake Up India       Political/Drama
# 8      OCT       25.0                Amdavad Junction           Crime/Drama
# 9      OCT       25.0                      Dilli Gang                 Crime
# 10     OCT       25.0                    Mickey Virus       Comedy/Thriller
# ...

# %%
df = df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)

# %%
#df3 = pd.read_html(str(tables[1]))[0]
 # avoided "ValueError: invalid literal for int() with base 10: '1"'
print(df3)
# Out:
#    Opening  Opening.1                                Title  \
# 0      APR          5                      Chashme Baddoor
# 1      APR         12                       Nautanki Saala
# 2      APR         12             Commando: A One Man Army
# 3      APR         19                        Ek Thi Daayan
# 4      APR         26                           Aashiqui 2
# 5      APR         26                                Shree
# 6      MAY          1                   Shootout at Wadala
# 7      MAY          1                       Bombay Talkies
# 8      MAY          1  Chhota Bheem and the Throne of Bali
# 9      MAY          4                        Savita Bhabhi
# 10     MAY         10                          Go Goa Gone
# 11     MAY         10                                Gippi
# 12     MAY         17                            Aurangzeb
# 13     MAY         17                        I Don't Luv U
# 14     MAY         17                 Beehad - The Ravines
# ...

# %%
#df.to_csv('film_2013.csv', header=False, index=False)

# %%
df
# Out:
#     Opening  Opening.1                   Title  \
# 0       OCT        2.0                Besharam
# 1       OCT       11.0       War Chhod Na Yaar
# 2       OCT       11.0          Baat Bann Gayi
# 3       OCT       11.0           Ek Thee Sanam
# 4       OCT       11.0  Paapi - Ek Satya Katha
# ..      ...        ...                     ...
# 112     SEP       20.0            The Lunchbox
# 113     SEP       27.0                 Warning
# 114     SEP       27.0                  Maazii
# 115     SEP       27.0                  Prague
# 116     SEP       27.0             Super Model
#
#                                Genre         Director  \
# 0                      Comedy/Action  Abhinav Kashyap
# 1                         War comedy     Faraz Haider
# 2                             Comedy        Shuja Ali
# 3                              Drama   Monish Kaushal
# 4                              Crime     Aziz Sejawal
# ..                               ...              ...
# ...

# %%
df.isnull().sum()
# Out:
# Opening       0
# Opening.1     1
# Title         1
# Genre         1
# Director      1
# Cast          2
# Source       86
# dtype: int64

# %%
df["Source"].fillna("unknown", inplace = True)

# %%
df.dropna()
# Out:
#     Opening  Opening.1                   Title  \
# 0       OCT        2.0                Besharam
# 1       OCT       11.0       War Chhod Na Yaar
# 2       OCT       11.0          Baat Bann Gayi
# 3       OCT       11.0           Ek Thee Sanam
# 4       OCT       11.0  Paapi - Ek Satya Katha
# ..      ...        ...                     ...
# 112     SEP       20.0            The Lunchbox
# 113     SEP       27.0                 Warning
# 114     SEP       27.0                  Maazii
# 115     SEP       27.0                  Prague
# 116     SEP       27.0             Super Model
#
#                                Genre         Director  \
# 0                      Comedy/Action  Abhinav Kashyap
# 1                         War comedy     Faraz Haider
# 2                             Comedy        Shuja Ali
# 3                              Drama   Monish Kaushal
# 4                              Crime     Aziz Sejawal
# ..                               ...              ...
# ...

# %%
cd /Users/pradeepvaddigadda/desktop
# Out:
# /Users/pradeepvaddigadda/Desktop

# %%
df.to_csv('cleanedfilm_2013.csv', header=True, index=True)
