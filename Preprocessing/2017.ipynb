# %%
import pandas as pd
import numpy as np
import requests
import bs4 as bs
import urllib.request

link = "https://en.wikipedia.org/wiki/List_of_Bollywood_films_of_2017"
source = urllib.request.urlopen(link).read()

soup = bs.BeautifulSoup(source,'lxml')



tables = soup.find_all('table',class_='wikitable')

len(tables)
# Out:
# 5

# %%
df1 = pd.read_html(str(tables[4]))[0]
df2 = pd.read_html(str(tables[1]))[0]
df3 = pd.read_html(str(tables[2]))[0]
df4 = pd.read_html(str(tables[3]).replace("'1\"\'",'"1"'))[0] # avoided "ValueError: invalid literal for int() with base 10: '1"'

# %%
df1
# Out:
#    Opening  Opening.1                     Title                  Director  \
# 0      OCT          6        Tu Hai Mera Sunday           Milind Dhaimade
# 1      OCT          6                      Chef        Raja Krishna Menon
# 2      OCT          6   Babuji Ek Ticket Bambai           Arvind Tripathi
# 3      OCT          6  Main Terrorist Nahi Hoon               Arjin Uppal
# 4      OCT         13            Ranchi Diaries           Sattwik Mohanty
# 5      OCT         19          Secret Superstar            Advait Chandan
# 6      OCT         20             Golmaal Again              Rohit Shetty
# 7      OCT         27               Jia aur Jia          Howard Rosemeyer
# 8      OCT         27                      Rukh           Atanu Mukherjee
# 9      NOV          3                   Ittefaq              Abhay Chopra
# 10     NOV          3       The House Next Door                Milind Rau
# 11     NOV          3                    Ribbon           Rakhee Sandilya
# ...

# %%
df = df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)

# %%
#df3 = pd.read_html(str(tables[1]))[0]
 # avoided "ValueError: invalid literal for int() with base 10: '1"'
print(df3)
# Out:
#    Opening  Opening.1                                 Title  \
# 0      APR          7  Laali Ki Shaadi Mein Laaddoo Deewana
# 1      APR          7                         Mirza Juuliet
# 2      APR          7                          Mukti Bhawan
# 3      APR         14                                Saanjh
# 4      APR         14                            Begum Jaan
# 5      APR         14                        Romeo-N-Bullet
# 6      APR         21                                  Noor
# 7      APR         21                  Ek Thi Rani Aisi Bhi
# 8      APR         21                                 Maatr
# 9      APR         21            Ajab Singh Ki Gajab Kahani
# 10     MAY          5                            Mantostaan
# 11     MAY         12                     Meri Pyaari Bindu
# 12     MAY         12                              Sarkar 3
# 13     MAY         19                       Half Girlfriend
# 14     MAY         19                        Jattu Engineer
# ...

# %%
#df.to_csv('film_2017.csv', header=False, index=False)

# %%
df
# Out:
#     Opening  Opening.1                     Title            Director  \
# 0       OCT        6.0        Tu Hai Mera Sunday     Milind Dhaimade
# 1       OCT        6.0                      Chef  Raja Krishna Menon
# 2       OCT        6.0   Babuji Ek Ticket Bambai     Arvind Tripathi
# 3       OCT        6.0  Main Terrorist Nahi Hoon         Arjin Uppal
# 4       OCT       13.0            Ranchi Diaries     Sattwik Mohanty
# ..      ...        ...                       ...                 ...
# 117     SEP       22.0            The Final Exit       Dhwanil Mehta
# 118     SEP       22.0                        JD   Shailendra Pandey
# 119     SEP       22.0            Haseena Parkar      Apoorva Lakhia
# 120     SEP       29.0                  Judwaa 2        David Dhawan
# 121     SEP        NaN                       NaN                 NaN
#
#                                                   Cast            Genre  \
# ...

# %%
df.isnull().sum()
# Out:
# Opening      0
# Opening.1    1
# Title        1
# Director     1
# Cast         1
# Genre        1
# Studio       3
# Ref.         1
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# Opening      0
# Opening.1    0
# Title        0
# Director     0
# Cast         0
# Genre        0
# Studio       0
# Ref.         0
# dtype: int64

# %%
df = df.drop('Ref.', 1)

# %%
cd /Users/pradeepvaddigadda/desktop
# Out:
# /Users/pradeepvaddigadda/Desktop

# %%
df
# Out:
#     Opening  Opening.1                    Title            Director  \
# 0       OCT        6.0       Tu Hai Mera Sunday     Milind Dhaimade
# 1       OCT        6.0                     Chef  Raja Krishna Menon
# 2       OCT        6.0  Babuji Ek Ticket Bambai     Arvind Tripathi
# 4       OCT       13.0           Ranchi Diaries     Sattwik Mohanty
# 5       OCT       19.0         Secret Superstar      Advait Chandan
# ..      ...        ...                      ...                 ...
# 116     SEP       22.0                   Bhoomi         Omung Kumar
# 117     SEP       22.0           The Final Exit       Dhwanil Mehta
# 118     SEP       22.0                       JD   Shailendra Pandey
# 119     SEP       22.0           Haseena Parkar      Apoorva Lakhia
# 120     SEP       29.0                 Judwaa 2        David Dhawan
#
#                                                   Cast            Genre  \
# 0                        Barun Sobti & Vishal Malhotra  Romantic comedy
# ...

# %%
df.to_csv('cleanedfilm_2017.csv', header=True, index=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-739f448a8ec1> in <module>
# ----> 1 df.to_csv('cleanedfilm_2017.csv', header=True, index=True)
#
# AttributeError: 'NoneType' object has no attribute 'to_csv'
