# %%
import pandas as pd
import numpy as np
import requests
import bs4 as bs
import urllib.request

link = "https://en.wikipedia.org/wiki/List_of_Bollywood_films_of_2010"
source = urllib.request.urlopen(link).read()

soup = bs.BeautifulSoup(source,'lxml')



tables = soup.find_all('table',class_='wikitable')

len(tables)
# Out:
# 5

# %%
df1 = pd.read_html(str(tables[4]))[0]
df2 = pd.read_html(str(tables[1]))[0]
df3 = pd.read_html(str(tables[2]))[0]
df4 = pd.read_html(str(tables[3]).replace("'1\"\'",'"1"'))[0] # avoided "ValueError: invalid literal for int() with base 10: '1"'

# %%
df1
# Out:
#    Opening  Opening.1                              Title  \
# 0      OCT        1.0                    Anjaana Anjaani
# 1      OCT        1.0                 Khichdi: The Movie
# 2      OCT        8.0                              Crook
# 3      OCT        8.0                     Do Dooni Chaar
# 4      OCT       15.0                            Aakrosh
# 5      OCT       15.0                             Pusher
# 6      OCT       15.0                          Knock Out
# 7      OCT       15.0                           Kajraare
# 8      OCT       15.0                 Ramayana: The Epic
# 9      OCT       22.0                              Hisss
# 10     OCT       22.0                    Jhootha Hi Sahi
# 11     OCT       22.0                     Rakta Charitra
# 12     OCT       29.0                          Maalik Ek
# 13     OCT       29.0                          Nakshatra
# 14     NOV        5.0                          Golmaal 3
# 15     NOV        5.0                     Action Replayy
# 16     NOV       12.0           Dunno Y... Na Jaane Kyon
# 17     NOV       12.0                             A Flat
# 18     NOV       12.0                 Ramaa: The Saviour
# 19     NOV       19.0                          Guzaarish
# 20     NOV       19.0  Shahrukh Bola "Khoobsurat Hai Tu"
# 21     NOV       19.0              Diwangi Ne Had Kar Di
# 22     NOV       26.0                    Allah Ke Banday
# 23     NOV       26.0                      Break Ke Baad
# 24     NOV       26.0                        Khuda Kasam
# 25     DEC        3.0           Khelein Hum Jee Jaan Sey
# 26     DEC        3.0                 Phas Gaye Re Obama
# 27     DEC        3.0                   Rakta Charitra 2
# 28     DEC       10.0                 Band Baaja Baaraat
# 29     DEC       10.0                         No Problem
# 30     DEC       17.0                332 Mumbai to India
# 31     DEC       17.0                            Payback
# 32     DEC       17.0                              Kaalo
# 33     DEC       17.0                              Mirch
# 34     DEC       24.0                     Tees Maar Khan
# 35     DEC       24.0                  Isi Life Mein...!
# 36     DEC       24.0              Toonpur Ka Super Hero
# 37     DEC       31.0               Tera Kya Hoga Johnny
# 38     DEC       31.0               Ada... A Way of Life
# 39     DEC        NaN                                NaN
# 40     DEC        NaN                                NaN
#
#                  Director                                               Cast  \
# 0         Siddharth Anand         Ranbir Kapoor, Priyanka Chopra, Zayed Khan
# 1          Aatish Kapadia  Supriya Pathak, Anang Desai, Rajeev Mehta, Jam...
# 2              Mohit Suri                         Emraan Hashmi, Neha Sharma
# 3            Habib Faisal                          Rishi Kapoor, Neetu Singh
# 4            Priyadarshan  Ajay Devgn, Akshaye Khanna, Bipasha Basu, Reem...
# 5              Assad Raja  Mahima Chaudhry, Pasha Bocarie, Marc Anwar, As...
# 6            Mani Shankar  Sanjay Dutt, Kangana Ranaut, Irrfan Khan, Guls...
# 7             Pooja Bhatt                     Himesh Reshammiya, Mona Laizza
# 8           Cheetan Desai                          Manoj Bajpai, Juhi Chawla
# 9          Jennifer Lynch                      Mallika Sherawat, Irrfan Khan
# 10         Abbas Tyrewala                       John Abraham, Pakhi Tyrewala
# 11        Ram Gopal Verma             Vivek Oberoi, Sudeep, Shatrughan Sinha
# 12      Deepak Balraj Vij                         Jackie Shroff, Divya Dutta
# 13         Mohan Savalkar                  Anupam Kher, Shubh, Sabina Sheema
# 14           Rohit Shetty  Ajay Devgn, Mithun Chakraborty, Tusshar Kapoor...
# 15             Vipul Shah  Akshay Kumar, Aishwarya Rai, Neha Dhupia, Rand...
# 16          Sanjay Sharma  Aryan Vaid, Kapil Sharma, Rituparna Sengupta, ...
# 17             Raaj Verma                        Sanjay Suri, Jimmy Shergill
# 18            Haadi Abrar      Sahil Khan, Tanushree Dutta, Dalip Singh Rana
# 19  Sanjay Leela Bhansali                      Hrithik Roshan, Aishwarya Rai
# 20      Makrand Deshpande  Preetika Chawla, Afzaal Khan, Shahrukh Khan, K...
# 21          Jiten Purohit                  Aditya Raj Kapoor, Deep, Ashhmita
# 22            Faruk Kabir       Sharman Joshi, Naseeruddin Shah, Faruk Kabir
# 23           Danish Aslam                       Imran Khan, Deepika Padukone
# 24            K C Bokadia      Sunny Deol, Tabu, Farida Jalal, Govind Namdeo
# 25     Ashutosh Gowariker  Abhishek Bachchan, Deepika Padukone, Sikander ...
# 26         Subhash Kapoor                          Rajat Kapoor, Neha Dhupia
# 27        Ram Gopal Verma     Suriya, Vivek Oberoi, Sudeep, Shatrughan Sinha
# 28         Maneesh Sharma                      Ranveer Singh, Anushka Sharma
# 29           Anees Bazmee  Anil Kapoor, Akshaye Khanna, Kangana Ranaut, N...
# 30          Mahesh Pandey                           Ali Asgar, Chetan Pandit
# 31      Sachin P. Karande             Munish Khan, Sara Khan, Gulshan Grover
# 32           Wilson Louis        Swini Khara, Aditya Srivastav, Gufi Paintal
# 33           Vinay Shukla  Konkona Sen Sharma, Raima Sen, Shahana Goswami...
# 34          Farah Khan[3]      Akshay Kumar,[3] Akshaye Khanna, Katrina Kaif
# 35         Vidhi Kasliwal         Akshay Oberoi, Sandeepa Dhar, Mohnish Behl
# 36         Kireet Khurana                                  Ajay Devgn, Kajol
# 37          Sudhir Mishra  Neil Nitin Mukesh, Soha Ali Khan, Kay Kay Meno...
# 38           Tanvir Ahmad  Ayaan Ahmad, Nauheed Cyrusi, Ayesha Jhulka, Ra...
# 39                    NaN                                                NaN
# 40                    NaN                                                NaN
#
#                       Genre
# 0                   Romance
# 1                    Comedy
# 2                  Thriller
# 3                    Comedy
# 4                  Thriller
# 5             Action, Drama
# 6                    Action
# 7                   Romance
# 8                 Animation
# 9           Horror/Thriller
# 10                  Romance
# 11             Biographical
# 12  Biographical, Animation
# 13                  Romance
# 14                   Comedy
# 15                   Comedy
# 16                  Romance
# 17                 Thriller
# 18        Action, Adventure
# 19                  Romance
# 20                 Thriller
# 21       Romance / Thriller
# 22                 Thriller
# 23                  Romance
# 24                   Action
# 25                   Period
# 26           Comedy / Crime
# 27             Biographical
# 28            Drama Romance
# 29                   Comedy
# 30                 Thriller
# 31                 Thriller
# 32                   Horror
# 33                    Drama
# 34            Action comedy
# 35                    Drama
# 36                 Animated
# 37                 Thriller
# 38                    Drama
# 39                      NaN
# 40                      NaN

# %%
df = df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)

# %%
#df3 = pd.read_html(str(tables[1]))[0]
 # avoided "ValueError: invalid literal for int() with base 10: '1"'
print(df3)
# Out:
#    Opening  Opening.1                      Title           Director  \
# 0      JAN        4.0     Humne Jeena Seekh Liya        Milind Ukey
# 1      JAN        4.0  Rama Rama Kya Hai Dramaa?    S. Chandrakaant
# 2      JAN       11.0                  Halla Bol  Rajkumar Santoshi
# 3      JAN       18.0          Bombay to Bangkok    Nagesh Kukunoor
# 4      JAN       18.0                      Tulsi         Ajay Kumar
# ..     ...        ...                        ...                ...
# 81     DEC       12.0        Rab Ne Bana Di Jodi      Aditya Chopra
# 82     DEC       19.0                      Wafaa      Rakesh Sawant
# 83     DEC       26.0                    Ghajini   A. R. Murugadoss
# 84     DEC       26.0                      Jumbo  Kompin Kemgumnird
# 85     DEC        NaN                        NaN                NaN
#
#                                                  Cast  \
# 0             Siddharth Chandekar, Mrunmayi Deshpande
# 1   Rajpal Yadav, Neha Dhupia, Aashish Chaudhary, ...
# 2              Ajay Devgn, Vidya Balan, Pankaj Kapoor
# 3                   Shreyas Talpade, Lena Christensen
# 4      Irrfan Khan, Manisha Koirala, Arzoo Govitrikar
# ..                                                ...
# 81                     Shah Rukh Khan, Anushka Sharma
# 82  Rajesh Khanna, Laila Khan, Shahib Chopra, Diya...
# 83         Aamir Khan, Asin, Jiah Khan, Pradeep Rawat
# 84  Akshay Kumar, Lara Dutta, Dimple Kapadia, Rajp...
# 85                                                NaN
#
#                                         Genre
# 0                                      Comedy
# 1                                      Comedy
# 2                                      Social
# 3                      Comedy, Drama, Romance
# 4                                         NaN
# ..                                        ...
# 81                                    Romance
# 82                    Romance, Drama, Romance
# 83  action, Drama, Mystery, Romance, Thriller
# 84                                  Animation
# 85                                        NaN
#
# [86 rows x 6 columns]

# %%
df.to_csv('film_2010.csv', header=False, index=False)

# %%
df
# Out:
#     Opening  Opening.1                        Title            Director  \
# 0       OCT        1.0              Anjaana Anjaani     Siddharth Anand
# 1       OCT        1.0           Khichdi: The Movie      Aatish Kapadia
# 2       OCT        8.0                        Crook          Mohit Suri
# 3       OCT        8.0               Do Dooni Chaar        Habib Faisal
# 4       OCT       15.0                      Aakrosh        Priyadarshan
# ..      ...        ...                          ...                 ...
# 121     AUG       27.0                      Soch Lo  Sartaj Singh Pannu
# 122     SEP        3.0                We Are Family  Siddharth Malhotra
# 123     SEP        3.0                      Mallika        Wilson Louis
# 124     SEP        3.0  The Film Emotional Atyachar        Akshay Shere
# 125     SEP       10.0                      Dabangg     Abhinav Kashyap
#
#                                                   Cast              Genre
# 0           Ranbir Kapoor, Priyanka Chopra, Zayed Khan            Romance
# 1    Supriya Pathak, Anang Desai, Rajeev Mehta, Jam...             Comedy
# 2                           Emraan Hashmi, Neha Sharma           Thriller
# 3                            Rishi Kapoor, Neetu Singh             Comedy
# 4    Ajay Devgn, Akshaye Khanna, Bipasha Basu, Reem...           Thriller
# ..                                                 ...                ...
# 121  Sartaj Singh Pannu, Barkha Madan, Bhupinder Singh  Mystery, Suspense
# 122                Arjun Rampal, Kajol, Kareena Kapoor     Drama, Romance
# 123       Sameer Dattani, Sheena Nayar, Himanshu Malik             Horror
# 124  Mohit Alawat, Kalki Koechlin, Vinay Pathak, Ra...              Drama
# 125  Salman Khan, Arbaaz Khan, Sonakshi Sinha, Sonu...             Action
#
# [126 rows x 6 columns]
